# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravGoel97/python/blob/master/IMDBproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/movies.csv")

# %% [markdown]
# Q1. How do we load a dataset and see first five rows?
#
# > Add blockquote

# %%
df.head(5)
# Out:
#            id                      name  year  rating certificate duration  \
# 0   tt0068646             The Godfather  1972     9.2           R  175 min
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG   87 min
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13  127 min
# 3   tt8115900              The Bad Guys  2022     6.9          PG  100 min
# 4  tt10809742                 Collision  2022     3.8       TV-MA   99 min
#
#                           genre    votes gross_income  \
# 0                  Crime, Drama  1798749  134,966,411
# 1  Animation, Adventure, Comedy    1,220  134,966,411
# 2         Crime, Drama, Mystery  121,063  134,966,411
# 3  Animation, Adventure, Comedy   23,090  134,966,411
# 4        Crime, Drama, Thriller      656  134,966,411
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %% [markdown]
# Q2. How do we load a dataset and see last five rows?

# %%
df.tail(5)
# Out:
#               id                                         name  year  rating  \
# 19803  tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804  tt0119621                      Mark Twain's America in  1998     6.5
# 19805  tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806  tt0267563                                       Hybrid  2000     7.4
# 19807  tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate duration                       genre votes gross_income  \
# 19803   Not Rated  112 min            Biography, Drama    41       44,435
# 19804           G   52 min      Documentary, Biography    48    2,281,741
# 19805   Not Rated   75 min      Documentary, Biography   125        9,188
# 19806   Not Rated   92 min      Documentary, Biography   146      159,403
# 19807          PG   98 min  Documentary, Comedy, Drama  2167      492,876
#
# ...

# %%
df.sample(1000)
# Out:
#               id                      name  year  rating certificate duration  \
# 15530  tt0088933                    Cocoon  1985     6.7       PG-13  117 min
# 6257   tt0090917             Deadly Friend  1986     5.5           R   91 min
# 13858  tt0082199                 Condorman  1981     5.7          PG   90 min
# 14947  tt2474310            Land of Storms  2014     6.8     Unrated  105 min
# 13994  tt0431213                    Lassie  2005     6.7          PG  100 min
# ...          ...                       ...   ...     ...         ...      ...
# 9569   tt0044926              Moulin Rouge  1952     7.0   Not Rated  119 min
# 2004   tt0783238             The Dead Girl  2006     6.6           R   85 min
# 8176   tt1835955  Errors of the Human Body  2012     5.2     Unrated  101 min
# 18698  tt0192023              Finder's Fee  2001     6.3           R  100 min
# 19519  tt9558612          PM Narendra Modi  2019     2.9   Not Rated  136 min
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  object
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#                year        rating
# count  19808.000000  19808.000000
# mean    1995.546597      6.041973
# std       22.801725      1.206831
# min     1894.000000      1.100000
# 25%     1983.000000      5.300000
# 50%     2003.000000      6.200000
# 75%     2014.000000      6.900000
# max     2022.000000      9.700000

# %%
df.duplicated().sum()  ##df.duplicated() will show the values as True/false while df.duplicated().sum() will give the sum of all the duplicate values
# Out:
# np.int64(0)

# %%
df.isnull().sum()  ##similary df.isnull() will show the values as True/false while df.null().sum() will give the sum of all the null values (if any)
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# 3. How can we clean the duration column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  object
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %%
df["year"].mode()[0]
# Out:
# np.int64(2018)

# %%
##df["duration"].mean()   ##why error? data type is string, should be int or float.

# %%
df["duration"] = df["duration"].str.replace("min","")

# %%
df["duration"] = df["duration"].str.replace(",", "")

# %%
print(df['duration'].dtype)
# Out:
# object

# %%
df["duration"] = df["duration"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 2.1+ MB

# %%
df["duration"].mean()
# Out:
# np.float64(101.77796849757674)

# %%
df["duration"].median()
# Out:
# 98.0

# %%
df["duration"].var()
# Out:
# 1864.401954130177

# %%
df["duration"].std()
# Out:
# 43.17872108029807

# %%
df["duration"].mode()[0]
# Out:
# np.int64(90)

# %%
##Q4. How do we clean the `gross` column and `votes` column?
##convert 'votes' and 'gross income' to integers

# %%
df["votes"] = df["votes"].str.replace(",","")

# %%
df["votes"] = df["votes"].astype(int)

# %%
print(df["votes"])
# Out:
# 0        1798749
# 1           1220
# 2         121063
# 3          23090
# 4            656
#           ...
# 19803         41
# 19804         48
# 19805        125
# 19806        146
# 19807       2167
# Name: votes, Length: 19808, dtype: int64

# %%
df["gross_income"] = df["gross_income"].str.replace("$","")

# %%
df["gross_income"] = df["gross_income"].str.replace("M","")

# %%
df["gross_income"] = df["gross_income"].str.replace(",","")

# %%
df["gross_income"] = df["gross_income"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  int64
#  8   gross_income    19808 non-null  float64
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 2.1+ MB

# %%
#Q5 how many missing values are there in each column?

df.isnull().sum()
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %%
###Q7 Find the hidden gems (high ratings, low votes)?

# %%
df.describe()
# Out:
#                year        rating      duration         votes  gross_income
# count  19808.000000  19808.000000  19808.000000  1.980800e+04  1.980800e+04
# mean    1995.546597      6.041973    101.777968  3.694303e+04  1.682198e+07
# std       22.801725      1.206831     43.178721  1.129755e+05  4.642034e+07
# min     1894.000000      1.100000      1.000000  5.000000e+00  0.000000e+00
# 25%     1983.000000      5.300000     90.000000  1.058000e+03  1.196010e+05
# 50%     2003.000000      6.200000     98.000000  4.233000e+03  1.158192e+06
# 75%     2014.000000      6.900000    111.000000  2.045350e+04  1.243278e+07
# max     2022.000000      9.700000   5220.000000  2.574832e+06  9.366622e+08

# %%
df['rating'] > 6.9
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 19803    False
# 19804    False
# 19805    False
# 19806     True
# 19807     True
# Name: rating, Length: 19808, dtype: bool

# %%
df[df['rating'] > 6.9]
# Out:
#               id                                  name  year  rating  \
# 0      tt0068646                         The Godfather  1972     9.2
# 1      tt5113044              Minions: The Rise of Gru  2022     7.3
# 5      tt0071562                 The Godfather Part II  1974     9.0
# 9      tt0071771                      The Longest Yard  1974     7.1
# 10     tt0993846               The Wolf of Wall Street  2013     8.2
# ...          ...                                   ...   ...     ...
# 19800  tt0044917                Amazing Monsieur Fabre  1951     7.0
# 19801  tt1334479                Yoo-Hoo, Mrs. Goldberg  2009     7.4
# 19802  tt1518255                             Raw Faith  2010     8.3
# 19806  tt0267563                                Hybrid  2000     7.4
# 19807  tt0116481  Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate  duration                          genre    votes  \
# 0               R       175                   Crime, Drama  1798749
# ...

# %%
df["votes"].mean()
# Out:
# np.float64(36943.027160743135)

# %%
df["votes"].median()
# Out:
# 4233.0

# %%
df[df['votes'] < 1058]
# Out:
#                id                                         name  year  rating  \
# 4      tt10809742                                    Collision  2022     3.8
# 33     tt13479592                                      Centaur  2022     5.3
# 47      tt1551614                                     Blowback  2022     4.4
# 463     tt0148615                                   Play Motel  1979     4.8
# 565     tt0026184                The Case of the Curious Bride  1935     6.6
# ...           ...                                          ...   ...     ...
# 19802   tt1518255                                    Raw Faith  2010     8.3
# 19803   tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804   tt0119621                      Mark Twain's America in  1998     6.5
# 19805   tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806   tt0267563                                       Hybrid  2000     7.4
#
# ...

# %%
df[(df['rating'] > 6.9) & (df['votes'] < 1058)]
# Out:
#                id                                               name  year  \
# 3423    tt4106286                                    Tiny Detectives  2014
# 3502    tt0042953                                          Shakedown  1950
# 3522    tt0070552                                         High Crime  1973
# 3594    tt0246879                                            Qurbani  1980
# 3980   tt13634096                                     The Bacon Hair  2020
# ...           ...                                                ...   ...
# 19799   tt1486548  Ahead of Time: The Extraordinary Journey of Ru...  2009
# 19800   tt0044917                             Amazing Monsieur Fabre  1951
# 19801   tt1334479                             Yoo-Hoo, Mrs. Goldberg  2009
# 19802   tt1518255                                          Raw Faith  2010
# 19806   tt0267563                                             Hybrid  2000
#
# ...

# %%
##Q8 Find the overhyped movies --low ratings-high gross
df[(df['rating']<5.3) & (df['gross_income']>12432780)]
# Out:
#                id                         name  year  rating certificate  \
# 4      tt10809742                    Collision  2022     3.8       TV-MA
# 18     tt11656220  Midnight in the Switchgrass  2021     4.4           R
# 37      tt6749318                  Speed Kills  2018     4.2           R
# 40      tt5433138            F9: The Fast Saga  2021     5.2       PG-13
# 47      tt1551614                     Blowback  2022     4.4           R
# ...           ...                          ...   ...     ...         ...
# 18575   tt1389139        When the Bough Breaks  2016     5.1       PG-13
# 18615   tt8170298                   John Henry  2020     3.6           R
# 18616   tt6469960          An Imperfect Murder  2017     3.2           R
# 18717   tt1859573             Pretty Obsession  2012     4.2   Not Rated
# 19592   tt0074562            Gable and Lombard  1976     5.1           R
#
#        duration                      genre   votes  gross_income directors_id  \
# ...

# %%
#Q9 what are unique certificates in the dataset?

df['certificate'].nunique()
# Out:
# 31

# %%
#Q10. how many movies were released each year?
df.groupby("year")["id"].count()
# Out:
# year
# 1894      1
# 1898      1
# 1902      2
# 1903      1
# 1913      3
#        ...
# 2018    736
# 2019    657
# 2020    467
# 2021    470
# 2022    174
# Name: id, Length: 114, dtype: int64

# %%
df['year'].value_counts().sort_index(ascending=False)
# Out:
# year
# 2022    174
# 2021    470
# 2020    467
# 2019    657
# 2018    736
#        ...
# 1913      3
# 1903      1
# 1902      2
# 1898      1
# 1894      1
# Name: count, Length: 114, dtype: int64

# %%
## Q11 What are 5 most common genres?

df.groupby("genre")["id"].count().sort_values(ascending = False).head(5)
# Out:
# genre
# Action, Crime, Drama      734
# Crime, Drama, Thriller    522
# Crime, Drama              430
# Drama, Thriller           422
# Horror                    411
# Name: id, dtype: int64

# %%
x = df['genre'].str.split(",").explode()
x = x.str.strip()

# %%
x.value_counts().sort_values(ascending = False)
# Out:
# genre
# Drama          9655
# Action         5290
# Crime          5244
# Comedy         4641
# Thriller       4231
# Adventure      3313
# Horror         3143
# Mystery        2211
# Romance        1815
# Biography      1582
# Fantasy        1447
# Sci-Fi         1399
# Music          1151
# Documentary    1001
# Family          888
# Animation       880
# War             861
# Western         785
# Sport           686
# History         531
# Film-Noir       335
# Short           191
# Musical         148
# News              9
# Reality-TV        1
# Game-Show         1
# Name: count, dtype: int64

# %%
# !python - version
# Out:
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
